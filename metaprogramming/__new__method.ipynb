# %%
"""
object.__new__(class, *args, **kwargs)
it is static method
-> not bound to object
-> class is the symbol for the class we want to instantiate
-> return new object of type class
"""

# %%
class Person:
    def __new__(cls, name, age):
        # can do things here

        instance = object.__new__(cls)
        # more code

        # and finally return the object we want
        return instance

# %%
class Point(object):
    pass

# %%
p = Point()

# %%
type(p)
# Out:
# __main__.Point

# %%
p = object.__new__(Point)

# %%
p

# %%
type(p)
# Out:
# __main__.Point

# %%
class Point(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = object.__new__(Point)

# %%
p.__dict__
# Out:
# {}

# %%
p.__init__(10, 20)

# %%
p.__dict__
# Out:
# {'x': 10, 'y': 20}

# %%
p = object.__new__(Point, 10, 20)

# %%
p.__dict__
# Out:
# {}
